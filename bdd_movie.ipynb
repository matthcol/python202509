# %% [markdown]
# # Base de Données Relationnelles

# %%
import psycopg2 as pg
from sqlalchemy import create_engine, text
import pandas as pd

# %%
user = 'movie'
password = 'mysecretpassword'
host = 'localhost'
port = 5432
dbname = 'dbmovie'

# %% [markdown]
# ## Connexion directe en DB API 2

# %%
conn = pg.connect(host=host, port=port, dbname=dbname, user=user, password=password)
conn
# Out:
# <connection object at 0x00000236A7FC2790; dsn: 'user=movie password=xxx dbname=dbmovie host=localhost port=5432', closed: 0>

# %%
conn.closed
# Out:
# 0

# %%
cursor = conn.cursor()
cursor
# Out:
# <cursor object at 0x00000236A8438200; closed: 0>

# %%
sql_movie_1983 = """SELECT
    id,
    title,
    year,
    duration
FROM movie
WHERE year = 1983
ORDER BY title"""

# %%
cursor.execute(sql_movie_1983)

# %%
for row in cursor:
    print(row)
# Out:
# (173893, "Hefty's", 1983, None)
# (86006, 'Never Say Never Again', 1983, 134)
# (86034, 'Octopussy', 1983, 131)
# (86250, 'Scarface', 1983, 170)
# (86190, 'Star Wars: Episode VI - Return of the Jedi', 1983, 131)
# (86361, 'Staying Alive', 1983, 93)
# (86383, 'Sudden Impact', 1983, 117)
# (86491, 'Twilight Zone: The Movie', 1983, 101)

# %%
cursor.close()

# %%
conn.close()
conn.closed
# Out:
# 1

# %%
with pg.connect(host=host, port=port, dbname=dbname, user=user, password=password) as conn2:
    # use resource conn
    with conn2.cursor() as cursor:
        cursor.execute(sql_movie_1983)
        data = list(cursor)
    # cursor.close()
# free resource: fin de transaction (TODO: encapsuler l'objet pour un auto close)
data
# Out:
# [(173893, "Hefty's", 1983, None),
#  (86006, 'Never Say Never Again', 1983, 134),
#  (86034, 'Octopussy', 1983, 131),
#  (86250, 'Scarface', 1983, 170),
#  (86190, 'Star Wars: Episode VI - Return of the Jedi', 1983, 131),
#  (86361, 'Staying Alive', 1983, 93),
#  (86383, 'Sudden Impact', 1983, 117),
#  (86491, 'Twilight Zone: The Movie', 1983, 101)]

# %%
# SQL with params year (1) and min duration (2)
sql_movie_year_duration = """SELECT
    id,
    title,
    year,
    duration
FROM movie
WHERE 
    year = %s
    AND duration >= %s
ORDER BY title"""

# %%
with conn2.cursor() as cursor:
    cursor.execute(sql_movie_year_duration, (1983, 120))
    data = list(cursor)
# cursor.close()
data
# Out:
# [(86006, 'Never Say Never Again', 1983, 134),
#  (86034, 'Octopussy', 1983, 131),
#  (86250, 'Scarface', 1983, 170),
#  (86190, 'Star Wars: Episode VI - Return of the Jedi', 1983, 131)]

# %%
# params: year et min_duration
sql_movie_year_duration2 = """SELECT
    id,
    title,
    year,
    duration
FROM movie
WHERE 
    year = %(year)s
    AND duration >= %(min_duration)s
ORDER BY title"""

# %%
with conn2.cursor() as cursor:
    cursor.execute(sql_movie_year_duration2, {'year':1984, 'min_duration': 100})
    data = list(cursor)
# cursor.close()
data
# Out:
# [(86927, 'Bachelor Party', 1984, 105),
#  (86984, 'Body Double', 1984, 114),
#  (87078, 'Conan the Destroyer', 1984, 103),
#  (87363, 'Gremlins', 1984, 106),
#  (87469, 'Indiana Jones and the Temple of Doom', 1984, 118),
#  (87727, 'Missing in Action', 1984, 101),
#  (88001, 'Rhinestone', 1984, 111),
#  (88161, 'Splash', 1984, 111),
#  (84750,
#   'Sword of the Valiant: The Legend of Sir Gawain and the Green Knight',
#   1984,
#   102),
#  (88247, 'The Terminator', 1984, 107),
#  (88272, 'Tightrope', 1984, 114)]

# %%
# MAUVAISE PRATIQUE: risque attaque par injection SQL
year = '1990 OR 1=1'
min_duration = '100 OR 1=1'
sql_movie_year_duration3 = f"""SELECT
    id,
    title,
    year,
    duration
FROM movie
WHERE 
    year = {year}
    AND duration >= {min_duration}
ORDER BY title""" 
with conn2.cursor() as cursor:
    cursor.execute(sql_movie_year_duration3)
    data = list(cursor)
# cursor.close()
data
# Out:
# [(1542344, '127 Hours', 2010, 94),
#  (2024544, '12 Years a Slave', 2013, 134),
#  (103594, '1492: Conquest of Paradise', 1992, 154),
#  (78723, '1941', 1979, 118),
#  (289043, '28 Days Later...', 2002, 113),
#  (1825784, '3 Geezers!', 2013, 81),
#  (40064, '3 Godfathers', 1948, 106),
#  (453562, '42', 2013, 128),
#  (1975249, '6 Bullets', 2012, 115),
#  (134273, '8MM', 1999, 123),
#  (3224458, 'A Beautiful Day in the Neighborhood', 2019, 109),
#  (92263, 'A Better Tomorrow', 1986, 95),
#  (94357, 'A Better Tomorrow II', 1987, 105),
#  (18710, 'A Blonde for a Night', 1928, 60),
#  (75784, 'A Bridge Too Far', 1977, 175),
#  (118548, 'Absolute Power', 1997, 121),
#  (50099, 'Action of the Tiger', 1957, 93),
#  (28554, "Adventure's End", 1937, 60),
#  (60414, 'A Fine Madness', 1966, 104),
#  (58461, 'A Fistful of Dollars', 1964, 99),
#  (14918, "A Fool's Awakening", 1924, 60),
#  (1815862, 'After Earth', 2013, 100),
#  (88680, 'After Hours', 1985, 97),
#  (4581576, 'Aftermath', 2017, 94),
#  (109920, 'A Good Man in Africa', 1994, 94),
#  (401445, 'A Good Year', 2006, 117),
#  (12260, 'A Heart to Let', 1921, 50),
#  (2980210, 'A Hologram for the King', 2016, 98),
#  (212720, 'A.I. Artificial Intelligence', 2001, 146),
#  (118571, 'Air Force One', 1997, 124),
#  (6139732, 'Aladdin', 2019, 128),
#  (11381, 'A Lady in Love', 1920, 50),
#  (9274, "A Lady's Name", 1918, 50),
#  (36092, 'A Lady Takes a Chance', 1943, 86),
#  (104694, 'A League of Their Own', 1992, 128),
#  (248667, 'Ali', 2001, 157),
#  (71115, "Alice Doesn't Live Here Anymore", 1974, 112),
#  (78748, 'Alien', 1979, 117),
#  (2316204, 'Alien: Covenant', 2017, 122),
#  (90605, 'Aliens', 1986, 137),
#  (2040578, 'Alien Uprising', 2012, 101),
#  (119535, 'A Life Less Ordinary', 1997, 103),
#  (31033, 'Allegheny Uprising', 1939, 81),
#  (411098, 'All the Invisible Children', 2005, 124),
#  (5294550, 'All the Money in the World', 2017, 132),
#  (16597, 'Almost a Lady', 1926, 60),
#  (96794, 'Always', 1989, 122),
#  (266465, 'A Man Apart', 2003, 109),
#  (33871, 'A Man Betrayed', 1941, 82),
#  (7763324, 'Amazing Stories', 1986, 111),
#  (51349, 'Ambush at Cimarron Pass', 1958, 73),
#  (765429, 'American Gangster', 2007, 157),
#  (69704, 'American Graffiti', 1973, 110),
#  (2179136, 'American Sniper', 2014, 133),
#  (118607, 'Amistad', 1997, 155),
#  (118577, 'An Alan Smithee Film: Burn Hollywood Burn', 1997, 86),
#  (1229340, 'Anchorman 2: The Legend Continues', 2013, 119),
#  (75993, 'An Enemy of the People', 1978, 103),
#  (39152, 'Angel and the Badman', 1947, 100),
#  (808151, 'Angels & Demons', 2009, 138),
#  (4155534, 'Animal Crackers', 2017, 105),
#  (17632, 'Annie Laurie', 1927, 90),
#  (51364, 'Another Time, Another Place', 1958, 91),
#  (6366, 'Anton the Terrible', 1916, 50),
#  (120587, 'Antz', 1998, 83),
#  (80377, 'Any Which Way You Can', 1980, 116),
#  (9475, 'A Pair of Silk Stockings', 1918, 60),
#  (107808, 'A Perfect World', 1993, 138),
#  (9492, 'A Petticoat Pilot', 1918, 50),
#  (78788, 'Apocalypse Now', 1979, 147),
#  (112384, 'Apollo 13', 1995, 140),
#  (22134, 'Arizona', 1931, 70),
#  (106308, 'Army of Darkness', 1992, 81),
#  (182392, 'A Roadside Impresario', 1917, 50),
#  (327437, 'Around the World in 80 Days', 2004, 120),
#  (1019452, 'A Serious Man', 2009, 106),
#  (120324, 'A Simple Plan', 1998, 121),
#  (1436568, 'Assassination Games', 2011, 101),
#  (112401, 'Assassins', 1995, 132),
#  (1135989, 'A Tale of Love and Darkness', 2015, 95),
#  (62373, 'A Time for Killing', 1967, 88),
#  (295178, 'Austin Powers in Goldmember', 2002, 94),
#  (499549, 'Avatar', 2009, 162),
#  (4154796, 'Avengers: Endgame', 2019, 181),
#  (4154756, 'Avengers: Infinity War', 2018, 149),
#  (275947, 'Avenging Angelo', 2002, 97),
#  (90264, 'A View to a Kill', 1985, 131),
#  (99077, 'Awakenings', 1990, 121),
#  (48971, 'Away All Boats', 1956, 114),
#  (19588, 'A Woman Against the World', 1928, 60),
#  (23775, 'Baby Face', 1933, 71),
#  (3138900, 'Babylon', 2014, 50),
#  (364970, 'Babylon A.D.', 2008, 90),
#  (58930, 'Baby the Rain Must Fall', 1965, 100),
#  (83605, 'Ba cai Lin Ya Zhen', 1982, 86),
#  (86927, 'Bachelor Party', 1984, 105),
#  (37522, 'Back to Bataan', 1945, 95),
#  (3588588, 'Backtrace', 2018, 92),
#  (112442, 'Bad Boys', 1995, 119),
#  (1502397, 'Bad Boys for Life', 2020, 124),
#  (172156, 'Bad Boys II', 2003, 147),
#  (92610, 'Bad Taste', 1987, 91),
#  (66808, 'Bananas', 1971, 82),
#  (185906, 'Band of Brothers', 2001, 594),
#  (16627, 'Bardelys the Magnificent', 1926, 90),
#  (269743, 'Barking Dogs Never Bite', 2000, 110),
#  (101410, 'Barton Fink', 1991, 116),
#  (372784, 'Batman Begins', 2005, 140),
#  (118688, 'Batman & Robin', 1997, 125),
#  (1699513, 'Beginning of the Great Revival', 2011, 140),
#  (138322, "Beretta's Island", 1993, 97),
#  (1830499, 'Beur sur la ville', 2011, 99),
#  (94737, 'Big', 1988, 104),
#  (66831, 'Big Jake', 1971, 110),
#  (44418, 'Big Jim McLain', 1952, 90),
#  (2513074, "Billy Lynn's Long Halftime Walk", 2016, 113),
#  (94747, 'Bird', 1988, 161),
#  (94750, 'Black Eagle', 1988, 93),
#  (413852, 'Black-Eyed Susan', 2004, 105),
#  (265086, 'Black Hawk Down', 2001, 144),
#  (19702, 'Blackmail', 1929, 85),
#  (96933, 'Black Rain', 1989, 125),
#  (5622412, 'Black Water', 2018, 104),
#  (83658, 'Blade Runner', 1982, 117),
#  (1856101, 'Blade Runner 2049', 2017, 164),
#  (47889, 'Blood Alley', 1955, 110),
#  (1634106, 'Bloodshot', 2020, 109),
#  (86979, 'Blood Simple', 1984, 99),
#  (92675, 'Bloodsport', 1988, 92),
#  (309377, 'Blood Work', 2002, 110),
#  (82085, 'Blow Out', 1981, 108),
#  (24902, 'Blue Steel', 1934, 54),
#  (86984, 'Body Double', 1984, 114),
#  (758774, 'Body of Lies', 2008, 128),
#  (181984, 'Boiler Room', 2000, 120),
#  (20702, 'Born Reckless', 1930, 82),
#  (28653, 'Born to the West', 1937, 59),
#  (68309, 'Boxcar Bertha', 1972, 88),
#  (72732, 'Brannigan', 1975, 111),
#  (86998, "Breakin'", 1984, 90),
#  (69822, 'Breezy', 1973, 106),
#  (3682448, 'Bridge of Spies', 2015, 142),
#  (5519340, 'Bright', 2017, 117),
#  (13891, 'Bright Lights of Broadway', 1923, 70),
#  (163988, 'Bringing Out the Dead', 1999, 121),
#  (115759, 'Broken Arrow', 1996, 108),
#  (80472, 'Bronco Billy', 1980, 116),
#  (328880, 'Brother Bear', 2003, 85),
#  (16690, 'Brown of Harvard', 1926, 85),
#  (252299, 'Buffalo Soldiers', 2001, 98),
#  (99426, 'Bullet in the Head', 1990, 136),
#  (1308729, 'Bullet to the Head', 2012, 92),
#  (62765, 'Bullitt', 1968, 114),
#  (887883, 'Burn After Reading', 2008, 96),
#  (69834, 'Cahill U.S. Marshal', 1973, 103),
#  (28677, 'California Straight Ahead!', 1937, 67),
#  (2639514, 'Campus Code', 2015, 110),
#  (68332, 'Cancel My Reservation', 1972, 99),
#  (74279, 'Cannonball!', 1976, 93),
#  (101540, 'Cape Fear', 1991, 128),
#  (72761, 'Capone', 1975, 101),
#  (1535109, 'Captain Phillips', 2013, 134),
#  (106519, "Carlito's Way", 1993, 144),
#  (74285, 'Carrie', 1976, 98),
#  (317219, 'Cars', 2006, 117),
#  (112641, 'Casino', 1995, 178),
#  (381061, 'Casino Royale', 2006, 144),
#  (112642, 'Casper', 1995, 100),
#  (60218, 'Cast a Giant Shadow', 1966, 146),
#  (162222, 'Cast Away', 2000, 143),
#  (97027, 'Casualties of War', 1989, 113),
#  (264464, 'Catch Me If You Can', 2002, 141),
#  (23878, 'Central Airport', 1933, 72),
#  (18756, 'Champagne', 1928, 86),
#  (824747, 'Changeling', 2008, 141),
#  (472062, "Charlie Wilson's War", 2007, 102),
#  (20759, 'Cheer Up and Smile', 1930, 76),
#  (65547, 'Chisum', 1970, 111),
#  (57952, 'Circus World', 1964, 135),
#  (87062, 'City Heat', 1984, 93),
#  (118863, 'Clay Pigeons', 1998, 104),
#  (109444, 'Clear and Present Danger', 1994, 141),
#  (106582, 'Cliffhanger', 1993, 113),
#  (75860, 'Close Encounters of the Third Kind', 1977, 138),
#  (1371111, 'Cloud Atlas', 2012, 172),
#  (90859, 'Cobra', 1986, 87),
#  (4682786, 'Collateral Beauty', 2016, 97),
#  (233469, 'Collateral Damage', 2002, 108),
#  (23899, 'College Coach', 1933, 76),
#  (88944, 'Commando', 1985, 90),
#  (82198, 'Conan the Barbarian', 1982, 129),
#  (87078, 'Conan the Destroyer', 1984, 103),
#  (3322364, 'Concussion', 2015, 123),
#  (27462, 'Conflict', 1936, 60),
#  (62824, "Coogan's Bluff", 1968, 93),
#  (118887, 'Cop Land', 1997, 105),
#  (409847, 'Cowboys & Aliens', 2011, 119),
#  (3076658, 'Creed', 2015, 133),
#  (6343314, 'Creed II', 2018, 130),
#  (88967, 'Crimewave', 1985, 83),
#  (924129, 'Crossing Over', 2009, 113),
#  (1173949, 'Crush and Blush', 2008, 101),
#  (79013, 'Cuba', 1979, 122),
#  (115994, 'Curdled', 1996, 88),
#  (97138, 'Cyborg', 1989, 86),
#  (37627, 'Dakota', 1945, 82),
#  (52722, "Darby O'Gill and the Little People", 1959, 93),
#  (32383, 'Dark Command', 1940, 94),
#  (99365, 'Darkman', 1990, 96),
#  (75906, 'Da sha xing yu xiao mei tou', 1978, 90),
#  (106673, 'Dave', 1993, 110),
#  (116040, 'Daylight', 1996, 114),
#  (103873, 'Dead Alive', 1992, 104),
#  (60287, 'Dead Heat on a Merry-Go-Round', 1966, 104),
#  (1028528, 'Death Proof', 2007, 127),
#  (72856, 'Death Race 2000', 1975, 80),
#  (99385, 'Death Warrant', 1990, 89),
#  (106697, 'Demolition Man', 1993, 115),
#  (298296, 'Derailed', 2002, 89),
#  (112851, 'Desperado', 1995, 104),
#  (112854, 'Destiny Turns on the Radio', 1995, 102),
#  (46912, 'Dial M for Murder', 1954, 105),
#  (66995, 'Diamonds Are Forever', 1971, 120),
#  (848557, 'Diary of the Dead', 2007, 95),
#  (246460, 'Die Another Day', 2002, 133),
#  (874886, 'Digital Short Films by Three Filmmakers 2004', 2004, 98),
#  (65641, "Dionysus in '69", 1970, 85),
#  (66999, 'Dirty Harry', 1971, 102),
#  (74415, 'Dixie Dynamite', 1976, 88),
#  (1853728, 'Django Unchained', 2012, 165),
#  (3282076, 'Domino', 2019, 89),
#  (57007, "Donovan's Reef", 1963, 109),
#  (6288124, "Don't Worry, He Won't Get Far on Foot", 2018, 114),
#  (2297164, 'Doomsday Book', 2012, 115),
#  (101764, 'Double Impact', 1991, 110),
#  (119013, 'Double Team', 1997, 93),
#  (1127180, 'Drag Me to Hell', 2009, 99),
#  (92925, 'Dragnet', 1987, 106),
#  (1735862, 'Dragon Eyes', 2012, 91),
#  (116136, 'DragonHeart', 1996, 103),
#  (100998, 'Dreams', 1990, 119),
#  (80661, 'Dressed to Kill', 1980, 104),
#  (132245, 'Driven', 2001, 116),
#  (55928, 'Dr. No', 1962, 110),
#  (134630, 'Duets', 2000, 112),
#  (5013056, 'Dunkirk', 2017, 106),
#  (23395, 'East of Shanghai', 1931, 92),
#  (11146, 'Easy to Get', 1920, 50),
#  (17843, 'Easy Virtue', 1927, 80),
#  (106793, 'Eddie Presley', 1992, 106),
#  (61619, 'El Dorado', 1967, 126),
#  (20852, 'Elstree Calling', 1930, 86),
#  (377057, 'Elvis Has Left the Building', 2004, 90),
#  (92965, 'Empire of the Sun', 1987, 153),
#  (1731141, "Ender's Game", 2013, 114),
#  (146675, 'End of Days', 1999, 122),
#  (2395199, 'Enemies Closer', 2013, 85),
#  (120660, 'Enemy of the State', 1998, 132),
#  (137494, 'Entrapment', 1999, 113),
#  (116213, 'Eraser', 1996, 115),
#  (50363, 'Escapade in Japan', 1957, 93),
#  (79116, 'Escape from Alcatraz', 1979, 112),
#  (1211956, 'Escape Plan', 2013, 115),
#  (6513656, 'Escape Plan 2: Hades', 2018, 96),
#  (6772804, 'Escape Plan: The Extractors', 2019, 97),
#  (83866, 'E.T. the Extra-Terrestrial', 1982, 115),
#  (91019, 'Every Time We Say Goodbye', 1986, 95),
#  (77523, 'Every Which Way but Loose', 1978, 114),
#  (92991, 'Evil Dead II', 1987, 84),
#  (5257, 'Excuse Me', 1915, 50),
#  (1528100, 'Exodus: Gods and Kings', 2014, 150),
#  (10099, 'Experimental Marriage', 1919, 50),
#  (1244659, 'Extraordinary Measures', 2010, 106),
#  (477302, 'Extremely Loud & Incredibly Close', 2011, 129),
#  (160184, 'Eye See You', 2002, 96),
#  (119094, 'Face/Off', 1997, 138),
#  (97328, 'Family Business', 1989, 110),
#  (74512, 'Family Plot', 1976, 120),
#  (72973, 'Farewell, My Lovely', 1975, 95),
#  (116282, 'Fargo', 1996, 98),
#  (1596343, 'Fast Five', 2011, 130),
#  (1013752, 'Fast & Furious', 2009, 107),
#  (1905041, 'Fast & Furious 6', 2013, 130),
#  (280665, 'Femme Fatale', 2002, 114),
#  (181536, 'Finding Forrester', 2000, 136),
#  (419749, 'Find Me Guilty', 2006, 125),
#  (13126, 'Find the Woman', 1922, 60),
#  (83943, 'Firefox', 1982, 136),
#  (59181, 'Firelight', 1964, 140),
#  (408345, 'Firewall', 2006, 105),
#  (83944, 'First Blood', 1982, 93),
#  (113071, 'First Knight', 1995, 134),
#  (77531, 'F.I.S.T.', 1978, 145),
#  (83947, 'Five Days One Summer', 1982, 96),
#  (418689, 'Flags of Our Fathers', 2006, 135),
#  (37702, 'Flame of Barbary Coast', 1945, 91),
#  (43547, 'Flying Leathernecks', 1951, 102),
#  (34742, 'Flying Tigers', 1942, 102),
#  (2381941, 'Focus', 2015, 105),
#  (154506, 'Following', 1998, 69),
#  (12180, 'Food for Scandal', 1920, 50),
#  (13140, 'Foolish Wives', 1922, 117),
#  (59578, 'For a Few Dollars More', 1965, 132),
#  (77572, 'Force 10 from Navarone', 1978, 118),
#  (32484, 'Foreign Correspondent', 1940, 120),
#  (126916, 'For Love of the Game', 1999, 137),
#  (109830, 'Forrest Gump', 1994, 142),
#  (40369, 'Fort Apache', 1948, 128),
#  (82398, 'For Your Eyes Only', 1981, 127),
#  (113101, 'Four Rooms', 1995, 98),
#  (18909, 'Four Sons', 1928, 100),
#  (48092, 'Francis in the Navy', 1955, 80),
#  (1795369, 'Frankenstein', 2011, 130),
#  (95174, 'Frantic', 1988, 120),
#  (68611, 'Frenzy', 1972, 116),
#  (116367, 'From Dusk Till Dawn', 1996, 108),
#  (57076, 'From Russia with Love', 1963, 115),
#  (120570, 'From the Earth to the Moon', 1998, 60),
#  (2820852, 'Furious 7', 2015, 137),
#  (113140, 'Galaxis', 1995, 91),
#  (217505, 'Gangs of New York', 2002, 167),
#  (1025100, 'Gemini Man', 2019, 117),
#  (208988, 'Get Carter', 2000, 102),
#  (65775, 'Getting Straight', 1970, 124),
#  (68637, 'Get to Know Your Rabbit', 1972, 91),
#  (119173, 'G.I. Jane', 1997, 125),
#  (116414, 'Girl 6', 1996, 108),
#  (54930, 'Girl on the Run', 1953, 64),
#  (10175, 'Girls', 1919, 50),
#  (21911, 'Girls Demand Excitement', 1931, 69),
#  (172495, 'Gladiator', 2000, 155),
#  (119207, "God Said, 'Ha!'", 1998, 85),
#  (113189, 'GoldenEye', 1995, 130),
#  (58150, 'Goldfinger', 1964, 110),
#  (18949, 'Golf Widows', 1928, 56),
#  (99685, 'Goodfellas', 1990, 146),
#  (9124, 'Good Night, Paul', 1918, 50),
#  (1205489, 'Gran Torino', 2008, 116),
#  (63036, 'Greetings', 1968, 88),
#  (87363, 'Gremlins', 1984, 106),
#  (6048922, 'Greyhound', 2020, 91),
#  (462322, 'Grindhouse', 2007, 191),
#  (1661382, 'Grudge Match', 2013, 113),
#  (2015381, 'Guardians of the Galaxy', 2014, 121),
#  (3896198, 'Guardians of the Galaxy Vol. 2', 2017, 136),
#  (101984, 'Guilty by Suspicion', 1991, 105),
#  (185446, 'Gu lian hua', 1985, None),
#  (475290, 'Hail, Caesar!', 2016, 106),
#  (77667, 'Ha luo, ye gui ren', 1978, None),
#  (448157, 'Hancock', 2008, 92),
#  (61747, "Hang 'Em High", 1968, 114),
#  (18972, "Hangman's House", 1928, 80),
#  (212985, 'Hannibal', 2001, 131),
#  (79268, 'Hanover Street', 1979, 109),
#  (10207, 'Happiness a la Mode', 1919, 50),
#  (104684, 'Hard Boiled', 1992, 128),
#  (107076, 'Hard Target', 1993, 97),
#  (56059, 'Hatari!', 1962, 157),
#  (22981, 'Haunted Gold', 1932, 58),
#  (10219, 'Hawthorne of the U.S.A.', 1919, 57),
#  (91187, 'Heartbreak Ridge', 1986, 130),
#  (110005, 'Heavenly Creatures', 1994, 99),
#  (173893, "Hefty's", 1983, None),
#  (826631, 'Heist School', 2006, 120),
#  (80850, "He Knows You're Alone", 1980, 94),
#  (51713, 'Hell Drivers', 1957, 108),
#  (63060, 'Hellfighters', 1968, 121),
#  (56062, 'Hell Is for Heroes', 1962, 90),
#  (16954, "Hell's Four Hundred", 1926, 60),
#  (89270, 'Heng cai san qian wan', 1987, 93),
#  (1798709, 'Her', 2013, 126),
#  (11282, 'Her Beloved Villain', 1920, 50),
#  (65832, 'Hercules in New York', 1970, 91),
#  (1212419, 'Hereafter', 2010, 129),
#  (13229, 'Her Gilded Cage', 1922, 60),
#  (76138, 'Heroes', 1977, 112),
#  (92264, 'Heroes Shed No Tears', 1984, 93),
#  (91203, 'Highlander', 1986, 116),
#  (102034, 'Highlander II: The Quickening', 1991, 91),
#  (68699, 'High Plains Drifter', 1973, 105),
#  (65836, 'Hi, Mom!', 1970, 87),
#  (24124, 'His Private Secretary', 1933, 60),
#  (386588, 'Hitch', 2005, 118),
#  (329717, 'Hollywood Homicide', 2003, 116),
#  (79302, 'Home Movies', 1979, 90),
#  (45883, 'Hondo', 1953, 83),
#  (84088, 'Honkytonk Man', 1982, 122),
#  (102057, 'Hook', 1991, 142),
#  (395169, 'Hotel Rwanda', 2004, 121),
#  (425112, 'Hot Fuzz', 2007, 121),
#  (56085, 'How the West Was Won', 1962, 164),
#  (82535, 'Hua ji shi dai', 1981, 101),
#  (970179, 'Hugo', 2011, 126),
#  (986233, 'Hunger', 2008, 96),
#  (480249, 'I Am Legend', 2007, 101),
#  (45897, 'I Confess', 1953, 95),
#  (29034, 'I Cover the War!', 1937, 68),
#  (29044, 'Idol of the Crowds', 1937, 60),
#  (88269, 'I Love Maria', 1988, 96),
#  (82880, "Il pap'occhio", 1980, 110),
#  (51757, 'I Married a Woman', 1958, 85),
#  (1356864, "I'm Still Here", 2010, 108),
#  (1375666, 'Inception', 2010, 148),
#  (1144804, 'Incredible Love', 2009, 142),
#  (116629, 'Independence Day', 1996, 145),
#  (367882, 'Indiana Jones and the Kingdom of the Crystal Skull', 2008, 122),
#  (97576, 'Indiana Jones and the Last Crusade', 1989, 127),
#  (87469, 'Indiana Jones and the Temple of Doom', 1984, 118),
#  (107212, 'Indian Summer', 1993, 97),
#  (3062096, 'Inferno', 2016, 121),
#  (139151, 'Inferno', 1999, 95),
#  (361748, 'Inglourious Basterds', 2009, 153),
#  (59309, "In Harm's Way", 1965, 165),
#  (339135, 'In Hell', 2003, 98),
#  (1791528, 'Inherent Vice', 2014, 148),
#  (104511, 'Innocent Blood', 1992, 112),
#  (34889, 'In Old California', 1942, 88),
#  (36038, 'In Old Oklahoma', 1943, 102),
#  (2042568, 'Inside Llewyn Davis', 2013, 104),
#  (278504, 'Insomnia', 2002, 118),
#  (816692, 'Interstellar', 2014, 169),
#  (107206, 'In the Line of Fire', 1993, 128),
#  (138524, 'Intolerable Cruelty', 2003, 100),
#  (95379, 'Intruder', 1989, 83),
#  (119381, 'Inventing the Abbotts', 1997, 110),
#  (1057500, 'Invictus', 2009, 134),
#  (343818, 'I, Robot', 2004, 115),
#  (3715320, 'Irrational Man', 2015, 95),
#  (45919, 'Island in the Sky', 1953, 109),
#  (79900, 'Itchy Fingers', 1979, 96),
#  (3501590, 'Ithaca', 2015, 96),
#  (273689, "It's All About Love", 2003, 104),
#  (76216, "It's Murder!", 1977, 70),
#  (119396, 'Jackie Brown', 1997, 154),
#  (31505, 'Jamaica Inn', 1939, 108),
#  (15022, 'Janice Meredith', 1924, 153),
#  (73195, 'Jaws', 1975, 124),
#  (1130988, 'JCVD', 2008, 97),
#  (1616195, 'J. Edgar', 2011, 137),
#  (1742044, 'Jersey Boys', 2014, 134),
#  (50562, 'Jet Pilot', 1957, 113),
#  (4818250, 'Jian Bing Man', 2015, 113),
#  (110197, 'Jimmy Hollywood', 1994, 112),
#  (116705, 'Jingle All the Way', 1996, 89),
#  (68768, 'Joe Kidd', 1972, 88),
#  (99892, 'Joe Versus the Volcano', 1990, 102),
#  (7286456, 'Joker', 2019, 122),
#  (6218010, 'Journey to China: The Mystery of Iron Mask', 2019, 120),
#  (63161, 'Journey to Shiloh', 1968, 101),
#  (113492, 'Judge Dredd', 1995, 96),
#  (110216, 'Junior', 1994, 109),
#  (68786, 'Junior Bonner', 1972, 100),
#  (21015, 'Juno and the Paycock', 1930, 85),
#  (107290, 'Jurassic Park', 1993, 127),
#  (113501, 'Just Cause', 1995, 102),
#  (94351, 'Just Heroes', 1989, 97),
#  (19044, 'Just Married', 1928, 60),
#  (65938, "Kelly's Heroes", 1970, 144),
#  (97659, 'Kickboxer', 1989, 97),
#  (5208950, 'Kickboxer: Retaliation', 2018, 110),
#  (3082898, 'Kickboxer: Vengeance', 2016, 90),
#  (6019206, 'Kill Bill: The Whole Bloody Affair', 2011, 247),
#  (266697, 'Kill Bill: Vol. 1', 2003, 111),
#  (378194, 'Kill Bill: Vol. 2', 2004, 137),
#  (5767628, "Kill 'Em All", 2017, 96),
#  (5689068, 'Killing Gunther', 2017, 92),
#  (99938, 'Kindergarten Cop', 1990, 111),
#  (320661, 'Kingdom of Heaven', 2005, 144),
#  (360717, 'King Kong', 2005, 187),
#  (27849, 'King of the Pecos', 1936, 54),
#  (211465, 'Knockaround Guys', 2001, 92),
#  (120724, 'Knock Off', 1998, 91),
#  (119485, 'Kundun', 1997, 134),
#  (1302011, 'Kung Fu Panda 2', 2011, 90),
#  (2267968, 'Kung Fu Panda 3', 2016, 95),
#  (349710, 'Ladder 49', 2004, 115),
#  (23109, 'Lady and Gent', 1932, 84),
#  (33806, 'Lady for a Night', 1942, 87),
#  (33808, 'Lady from Louisiana', 1941, 82),
#  (48279, 'Lady Godiva of Coventry', 1955, 89),
#  (51840, 'Lafayette Escadrille', 1958, 93),
#  (1583420, 'Larry Crowne', 2011, 98),
#  (107362, 'Last Action Hero', 1993, 130),
#  (77655, 'Last Hurrah for Chivalry', 1979, 106),
#  (26614, 'Lawless Range', 1935, 53),
#  (89469, 'Legend', 1985, 94),
#  (50629, 'Legend of the Lost', 1957, 109),
#  (126388, 'Legionnaire', 1998, 99),
#  (67334, 'Le Mans', 1971, 106),
#  (19085, "Let 'Er Go Gallegher", 1928, 60),
#  (48294, "Let's Make Up", 1954, 94),
#  (498380, 'Letters from Iwo Jima', 2006, 141),
#  (97742, 'Licence to Kill', 1989, 133),
#  (37017, 'Lifeboat', 1944, 97),
#  (443272, 'Lincoln', 2012, 150),
#  (100029, 'Lionheart', 1990, 108),
#  (185431, 'Little Nicky', 2000, 90),
#  (14205, 'Little Old New York', 1923, 110),
#  (70328, 'Live and Let Die', 1973, 121),
#  (97770, 'Lock Up', 1989, 109),
#  (2305700, 'London 2012 Olympic Opening Ceremony: Isles of Wonder', 2012, 352),
#  (22093, 'Love in High Gear', 1932, 66),
#  (16048, 'Lovers in Quarantine', 1925, 70),
#  (12413, "Love's Redemption", 1921, 72),
#  (57263, 'Love with the Proper Stranger', 1963, 102),
#  (61927, 'Luv', 1967, 93),
#  (107478, 'Made in America', 1993, 111),
#  (1881002, 'Maggie', 2015, 95),
#  (70355, 'Magnum Force', 1973, 124),
#  (22109, 'Maker of Men', 1931, 71),
#  (4537986, 'Manhunt', 2017, 106),
#  (95583, 'Maniac Cop', 1988, 85),
#  (100107, 'Maniac Cop 2', 1990, 90),
#  (1164607, 'Man zhou ren', 1973, 89),
#  (58329, 'Marnie', 1964, 130),
#  (21128, 'Mary', 1931, 78),
#  (5360996, 'Mary Magdalene', 2018, 120),
#  (457409, 'Mass of Angels', 2004, 85),
#  (325805, 'Matchstick Men', 2003, 116),
#  (117011, 'Maximum Risk', 1996, 101),
#  (14264, 'Maytime', 1923, 80),
#  (57298, 'McLintock!', 1963, 127),
#  (71824, 'McQ', 1974, 111),
#  (70379, 'Mean Streets', 1973, 112),
#  (104839, 'Medicine Man', 1992, 106),
#  (97858, 'Meet the Feebles', 1989, 97),
#  (209144, 'Memento', 2000, 113),
#  (95613, 'Memories of Me', 1988, 105),
#  (353969, 'Memories of Murder', 2003, 131),
#  (119654, 'Men in Black', 1997, 98),
#  (1409024, 'Men in Black 3', 2012, 106),
#  (120912, 'Men in Black II', 2002, 88),
#  (21140, 'Men Without Women', 1930, 77),
#  (79550, 'Meteor', 1979, 108),
#  (167988, 'Michael Jackson: Video Greatest Hits - HIStory', 1995, 89),
#  (119668, 'Midnight in the Garden of Good and Evil', 1997, 155),
#  (100150, "Miller's Crossing", 1990, 115),
#  (405159, 'Million Dollar Baby', 2004, 132),
#  (366777, 'Millions', 2004, 98),
#  (181689, 'Minority Report', 2002, 145),
#  (11469, 'Miss Hobbs', 1920, 60),
#  (87727, 'Missing in Action', 1984, 101),
#  (117060, 'Mission: Impossible', 1996, 110),
#  (120755, 'Mission: Impossible II', 2000, 123),
#  (183523, 'Mission to Mars', 2000, 114),
#  (82762, 'Mo deng tian shi', 1982, 88),
#  (178762, 'Molly Entangled', 1917, 50),
#  (87739, 'Monaco Forever', 1984, 48),
#  (76012, 'Money Crazy', 1977, 92),
#  (79574, 'Moonraker', 1979, 126),
#  (79576, 'More American Graffiti', 1979, 110),
#  (1126618, 'Morning Glory', 2010, 107),
#  (1216496, 'Mother', 2009, 129),
#  (19182, 'Mother Machree', 1927, 75),
#  (33922, 'Mr. & Mrs. Smith', 1941, 95),
#  (9403, "Mrs. Leffingwell's Boots", 1918, 50),
#  (106074, "Mr. Wroe's Virgins", 1993, 50),
#  (408306, 'Munich', 2005, 164),
#  (21165, 'Murder!', 1930, 104),
#  (163114, 'Murder à la Mod', 1968, 80),
#  (71877, 'Murder on the Orient Express', 1974, 128),
#  (359715, "My Best Friend's Birthday", 1987, 90),
#  (327056, 'Mystic River', 2003, 138),
#  (381442, 'Narco', 2004, 105),
#  (24805, "'Neath the Arizona Skies", 1934, 52),
#  (60748, 'Nevada Smith', 1966, 128),
#  (51987, 'Never Love a Stranger', 1958, 91),
#  (49547, 'Never Say Goodbye', 1956, 96),
#  (86006, 'Never Say Never Again', 1983, 134),
#  (53108, 'Never So Few', 1959, 125),
#  (31718, 'New Frontier', 1939, 57),
#  (808399, 'New York, I Love You', 2008, 103),
#  (76451, 'New York, New York', 1977, 155),
#  (97965, 'New York Stories', 1989, 124),
#  (18201, 'Night Bride', 1927, 60),
#  (82817, 'Nighthawks', 1981, 99),
#  (1838609,
#   'Night of the Day of the Dawn of the Son of the Bride of the Return of the Revenge of the Terror of the Attack of the Evil Mutant Hellbound Flesh Eating Crawling Alien Zombified Subhumanoid Living Dead, Part 5',
#   2011,
#   84),
#  (475343,
#   'Night of the Day of the Dawn of the Son of the Bride of the Return of the Revenge of the Terror of the Attack of the Evil, Mutant, Hellbound, Flesh-Eating Subhumanoid Zombified Living Dead, Part 3',
#   2005,
#   80),
#  (230575,
#   'Night of the Day of the Dawn of the Son of the Bride of the Return of the Terror',
#   1991,
#   96),
#  (20223, "Noah's Ark", 1928, 135),
#  (310000, 'No Blood No Tears', 2002, 116),
#  (142692, 'No Control', 1927, 60),
#  (477348, 'No Country for Old Men', 2007, 122),
#  (66156, 'No Place to Hide', 1973, 80),
#  (89695, 'No Retreat, No Surrender', 1986, 85),
#  (50772, 'No Road Back', 1957, 83),
#  (53125, 'North by Northwest', 1959, 136),
#  (54127, 'North to Alaska', 1960, 122),
#  (91653, 'Nothing in Common', 1986, 118),
#  (38787, 'Notorious', 1946, 102),
#  (107711, 'Nowhere to Run', 1993, 94),
#  (13444, 'Number 13', 1922, None),
#  (23285, 'Number 17', 1932, 66),
#  (190590, 'O Brother, Where Art Thou?', 2000, 107),
#  (74991, 'Obsession', 1976, 98),
#  (86034, 'Octopussy', 1983, 131),
#  (11527, 'Oh, Lady, Lady', 1920, 50),
#  (3967856, 'Okja', 2017, 120),
#  (101020, 'Once a Thief', 1991, 108),
#  (7131622, 'Once Upon a Time... in Hollywood', 2019, 161),
#  (64757, "On Her Majesty's Secret Service", 1969, 142),
#  (8384, 'On the Level', 1917, 50),
#  (43887, 'Operation Pacific', 1951, 111),
#  (55262, 'Operation Snafu', 1961, 89),
#  (102603, 'Oscar', 1991, 109),
#  (82869, 'Outland', 1981, 109),
#  (30545, 'Overland Stage Raiders', 1938, 55),
#  (93692, 'Over the Top', 1987, 93),
#  (1623205, 'Oz The Great and Powerful', 2013, 130),
#  (64782, 'Paint Your Wagon', 1969, 164),
#  (89767, 'Pale Rider', 1985, 115),
#  (30550, 'Pals of the Saddle', 1938, 55),
#  (70511, 'Papillon', 1973, 151),
#  (78056, 'Paradise Alley', 1978, 107),
#  (26846, 'Paradise Canyon', 1935, 52),
#  (1413495, 'Paranoia', 2013, 106),
#  (6751668, 'Parasite', 2019, 132),
#  (98067, 'Parenthood', 1989, 124),
#  (401711, "Paris, je t'aime", 2006, 120),
#  (1829012, 'Passion', 2012, 102),
#  (12555, 'Passion Flower', 1921, 84),
#  (105112, 'Patriot Games', 1992, 117),
#  (1092026, 'Paul', 2011, 104),
#  (338337, 'Paycheck', 2003, 119),
#  (71994, 'Phantom of the Paradise', 1974, 91),
#  (107818, 'Philadelphia', 1993, 125),
#  (98097, 'Pink Cadillac', 1989, 122),
#  (82910, 'Piranha II: The Spawning', 1981, 94),
#  (134847, 'Pitch Black', 2000, 109),
#  (35195, 'Pittsburgh', 1942, 92),
#  (1077258, 'Planet Terror', 2007, 105),
#  (145734, 'Playing by Heart', 1998, 121),
#  (67588, 'Play Misty for Me', 1971, 102),
#  (3488328, 'Pound of Flesh', 2015, 104),
#  (93773, 'Predator', 1987, 107),
#  (100404, 'Presumed Innocent', 1990, 127),
#  (72872, 'Princess Chang Ping', 1976, 102),
#  (1446714, 'Prometheus', 2012, 124),
#  (16251, 'Proud Flesh', 1925, 70),
#  (54215, 'Psycho', 1960, 109),
#  (110912, 'Pulp Fiction', 1994, 154),
#  (95927, 'Punchline', 1988, 128),
#  (76580, 'Qian zuo guai', 1980, 101),
#  (830515, 'Quantum of Solace', 2008, 106),
#  (180073, 'Quills', 2000, 124),
#  (110932, 'Quiz Show', 1994, 133),
#  (105211, 'Radio Flyer', 1992, 114),
#  (81398, 'Raging Bull', 1980, 129),
#  (82971, 'Raiders of the Lost Ark', 1981, 115),
#  (26908, 'Rainbow Valley', 1935, 52),
#  (93822, 'Raising Arizona', 1987, 94),
#  (105217, 'Raising Cain', 1992, 92),
#  (5848272, 'Ralph Breaks the Internet', 2018, 112),
#  (462499, 'Rambo', 2008, 92),
#  (89880, 'Rambo: First Blood Part II', 1985, 96),
#  (95956, 'Rambo III', 1988, 102),
#  (1206885, 'Rambo: Last Blood', 2019, 89),
#  (156934, 'Random Hearts', 1999, 133),
#  (25699, 'Randy Rides Alone', 1934, 52),
#  (2865120, 'Ratchet & Clank', 2016, 94),
#  (91828, 'Raw Deal', 1986, 106),
#  (959306, 'Reach Me', 2014, 95),
#  (1677720, 'Ready Player One', 2018, 140),
#  (35244, 'Reap the Wild Wind', 1942, 123),
#  (47396, 'Rear Window', 1954, 112),
#  (32976, 'Rebecca', 1940, 130),
#  (100992, 'Rebel from China', 1990, 91),
#  (937237, 'Redacted', 2007, 90),
#  (425637, 'Red Cliff', 2008, 146),
#  (1326972, 'Red Cliff II', 2009, 142),
#  (95963, 'Red Heat', 1988, 104),
#  (40724, 'Red River', 1948, 133),
#  (30663, 'Red River Range', 1938, 56),
#  (89893, 'Red Sonja', 1985, 89),
#  (102768, 'Regarding Henry', 1991, 108),
#  (1460743, 'Reign of Assassins', 2010, 117),
#  (238552, 'Replicant', 2001, 100),
#  (831884, 'Reservation Road', 2007, 102),
#  (105236, 'Reservoir Dogs', 1992, 99),
#  (124595, 'Return to Paradise', 1998, 111),
#  (35250, 'Reunion in France', 1942, 104),
#  (48554, 'Revenge of the Creature', 1955, 82),
#  (88001, 'Rhinestone', 1984, 111),
#  (3513548, 'Richard Jewell', 2019, 131),
#  (1411250, 'Riddick', 2013, 119),
#  (23396, 'Ride Him, Cowboy', 1932, 55),
#  (24500, 'Riders of Destiny', 1933, 53),
#  (53221, 'Rio Bravo', 1959, 141),
#  (42895, 'Rio Grande', 1950, 105),
#  (66301, 'Rio Lobo', 1970, 114),
#  (107969, 'Rising Sun', 1993, 125),
#  (257044, 'Road to Perdition', 2002, 117),
#  (75147, 'Robin and Marian', 1976, 106),
#  (955308, 'Robin Hood', 2010, 140),
#  (102798, 'Robin Hood: Prince of Thieves', 1991, 143),
#  (75148, 'Rocky', 1976, 120),
#  (479143, 'Rocky Balboa', 2006, 102),
#  (79817, 'Rocky II', 1979, 119),
#  (84602, 'Rocky III', 1982, 99),
#  (89927, 'Rocky IV', 1985, 91),
#  (100507, 'Rocky V', 1990, 104),
#  (10637, 'Romance and Arabella', 1919, 50),
#  (73636, 'Rooster Cogburn', 1975, 108),
#  (40746, 'Rope', 1948, 80),
#  (111022, 'Rotwang muß weg!', 1994, 82),
#  (21319, 'Rough Romance', 1930, 55),
#  (90557, "'Round Midnight", 1986, 133),
#  (18350, 'Rubber Tires', 1927, 70),
#  (89482, 'Run Tiger, Run', 1985, 91),
#  (93898, 'Russkies', 1987, 99),
#  (1728245, 'Rzhevskiy protiv Napoleona', 2012, 95),
#  (28212, 'Sabotage', 1936, 76),
#  (1742334, 'Sabotage', 2014, 109),
#  (35279, 'Saboteur', 1942, 109),
#  (114319, 'Sabrina', 1995, 127),
#  (24516, 'Sagebrush Trail', 1933, 54),
#  (20359, 'Salute', 1929, 84),
#  (1813593, 'Sam Raimi Early Shorts', 1985, 157),
#  (26966, 'Sanders of the River', 1935, 98),
#  (41841, 'Sands of Iwo Jima', 1949, 100),
#  (17344, 'Sandy', 1926, 80),
#  (30714, 'Santa Fe Stampede', 1938, 55),
#  (9576, 'Sauce for the Goose', 1918, 50),
#  (2140373, 'Saving Mr. Banks', 2013, 125),
#  (120815, 'Saving Private Ryan', 1998, 169),
#  (86250, 'Scarface', 1983, 170),
#  (79858, 'Scavenger Hunt', 1979, 116),
#  (108052, "Schindler's List", 1993, 195),
#  (114371, 'Search and Destroy', 1995, 90),
#  (28227, 'Sea Spoilers', 1936, 63),
#  (458471, 'Second in Command', 2006, 92),
#  (28231, 'Secret Agent', 1936, 86),
#  (814314, 'Seven Pounds', 2008, 123),
#  (33038, 'Seven Sinners', 1940, 87),
#  (323939, 'Shade', 2003, 101),
#  (36342, 'Shadow of a Doubt', 1943, 108),
#  (13592, 'Shadows', 1922, 70),
#  (63592, 'Shalako', 1968, 113),
#  (111149, 'Shallow Grave', 1994, 89),
#  (1723811, 'Shame', 2011, 101),
#  (307453, 'Shark Tale', 2004, 90),
#  (1767372, "She's Funny That Way", 2014, 93),
#  (41866, 'She Wore a Yellow Ribbon', 1949, 104),
#  (1130884, 'Shutter Island', 2010, 138),
#  (286106, 'Signs', 2002, 106),
#  (490215, 'Silence', 2016, 161),
#  (401792, 'Sin City', 2005, 124),
#  (851471, 'Sir Billi', 2012, 76),
#  (70698, 'Sisters', 1972, 93),
#  (120828, 'Six Days Seven Nights', 1998, 102),
#  (108149, 'Six Degrees of Separation', 1993, 112),
#  (1074638, 'Skyfall', 2012, 143),
#  (108160, 'Sleepless in Seattle', 1993, 105),
#  (111218, 'Sleep with Me', 1994, 86),
#  (1010048, 'Slumdog Millionaire', 2008, 120),
#  (13611, "Smilin' Through", 1922, 96),
#  (120832, 'Snake Eyes', 1998, 98),
#  (1706620, 'Snowpiercer', 2013, 126),
#  (57517, 'Soldier in the Rain', 1963, 88),
#  (1286146, 'Soldiers', 2014, 108),
#  (111237, 'Somebody to Love', 1994, 102),
#  (49778, 'Somebody Up There Likes Me', 1956, 113),
#  (94008, 'Someone to Watch Over Me', 1987, 106),
#  (24592, 'Somewhere in Sonora', 1933, 59),
#  (91993, 'SpaceCamp', 1986, 107),
#  (186566, 'Space Cowboys', 2000, 130),
#  (20438, 'Speakeasy', 1929, 62),
#  (2379713, 'Spectre', 2015, 148),
#  (38109, 'Spellbound', 1945, 111),
#  (145487, 'Spider-Man', 2002, 121),
#  (316654, 'Spider-Man 2', 2004, 127),
#  (413300, 'Spider-Man 3', 2007, 139),
#  (5814534, 'Spies in Disguise', 2019, 102),
#  (90056, 'Spies Like Us', 1985, 102),
#  (88161, 'Splash', 1984, 111),
#  (338459, 'Spy Kids 3-D: Game Over', 2003, 84),
#  (31971, 'Stagecoach', 1939, 96),
#  (42994, 'Stage Fright', 1950, 110),
#  (49793, 'Star in the Dust', 1956, 80),
#  (95405, 'Starry is the Night', 1988, 94),
#  (76759, 'Star Wars: Episode IV - A New Hope', 1977, 121),
#  (2527338, 'Star Wars: Episode IX - The Rise of Skywalker', 2019, 142),
#  (2488496, 'Star Wars: Episode VII - The Force Awakens', 2015, 138),
#  (86190, 'Star Wars: Episode VI - Return of the Jedi', 1983, 131),
#  (80684, 'Star Wars: Episode V - The Empire Strikes Back', 1980, 124),
#  (75268, 'Stay Hungry', 1976, 102),
#  (86361, 'Staying Alive', 1983, 93),
#  (2080374, 'Steve Jobs', 2015, 122),
#  (105477, 'Stop! Or My Mom Will Shoot', 1992, 87),
#  (44079, 'Strangers on a Train', 1951, 101),
#  (24747, "Strauss' Great Waltz", 1934, 81),
#  (149171, 'Strays', 1997, 105),
#  (111301, 'Street Fighter', 1994, 102),
#  (7255568, 'Student of the Year 2', 2019, 146),
#  (9666, 'Such a Little Pirate', 1918, 50),
#  (114576, 'Sudden Death', 1995, 111),
#  (86383, 'Sudden Impact', 1983, 117),
#  (1386697, 'Suicide Squad', 2016, 123),
#  (906665, 'Sukiyaki Western Django', 2007, 121),
#  (3263904, 'Sully', 2016, 96),
#  (448134, 'Sunshine', 2007, 107),
#  (34248, 'Suspicion', 1941, 99),
#  (2112277, 'Swelter', 2014, 96),
#  (84750,
#   'Sword of the Valiant: The Legend of Sir Gawain and the Green Knight',
#   1984,
#   102),
#  (2763304, 'T2 Trainspotting', 2017, 117),
#  (37343, 'Tall in the Saddle', 1944, 87),
#  (98439, 'Tango & Cash', 1989, 104),
#  (48696, 'Tarantula', 1955, 80),
#  (53334, "Tarzan's Greatest Adventure", 1959, 88),
#  (133285, 'Task Force', 1997, 110),
#  (295721, 'Taxi 3', 2003, 84),
#  (75314, 'Taxi Driver', 1976, 114),
#  (103064, 'Terminator 2: Judgment Day', 1991, 137),
#  (181852, 'Terminator 3: Rise of the Machines', 2003, 109),
#  (6450804, 'Terminator: Dark Fate', 2019, 128),
#  (1340138, 'Terminator Genisys', 2015, 126),
#  (4824394, 'Terminator Genisys: The YouTube Chronicles', 2015, None),
#  (23567, 'Texas Cyclone', 1932, 63),
#  (27087, 'Texas Terror', 1935, 51),
#  (16420, 'That Royle Girl', 1925, 114),
#  (23576, "That's My Boy", 1932, 71),
#  (117887, 'That Thing You Do!', 1996, 108),
#  (6802308, 'The 15:17 to Paris', 2018, 94),
#  (26029, 'The 39 Steps', 1935, 86),
#  (216216, 'The 6th Day', 2000, 123),
#  (96754, 'The Abyss', 1989, 171),
#  (983193, 'The Adventures of Tintin', 2011, 107),
#  (1655441, 'The Age of Adaline', 2015, 112),
#  (106226, 'The Age of Innocence', 1993, 139),
#  (53580, 'The Alamo', 1960, 162),
#  (66767, 'The Anderson Tapes', 1971, 99),
#  (118661, 'The Avengers', 1998, 89),
#  (14689, 'The Average Woman', 1924, 64),
#  (338751, 'The Aviator', 2004, 170),
#  (6412452, 'The Ballad of Buster Scruggs', 2018, 133),
#  (101999, 'The Banquet', 1991, 97),
#  (51398, 'The Barbarian and the Geisha', 1958, 105),
#  (163978, 'The Beach', 2000, 119),
#  (66819, 'The Beguiled', 1971, 105),
#  (3691740, 'The BFG', 2016, 117),
#  (118715, 'The Big Lebowski', 1998, 117),
#  (22681, 'The Big Stampede', 1932, 54),
#  (20691, 'The Big Trail', 1930, 125),
#  (56869, 'The Birds', 1963, 119),
#  (387877, 'The Black Dahlia', 2006, 121),
#  (19699, 'The Black Watch', 1929, 93),
#  (51418, 'The Blob', 1958, 86),
#  (80455, 'The Blues Brothers', 1980, 133),
#  (99165, 'The Bonfire of the Vanities', 1990, 125),
#  (7816392, 'The Bouncer', 2018, 94),
#  (112579, 'The Bridges of Madison County', 1995, 135),
#  (96734, "The 'Burbs", 1989, 102),
#  (7504726, 'The Call of the Wild', 2020, 100),
#  (296572, 'The Chronicles of Riddick', 2004, 119),
#  (59037, 'The Cincinnati Kid', 1965, 102),
#  (4287320, 'The Circle', 2017, 110),
#  (90863, 'The Color of Money', 1986, 119),
#  (88939, 'The Color Purple', 1985, 154),
#  (54757, 'The Comancheros', 1961, 107),
#  (49092, 'The Conqueror', 1956, 111),
#  (71360, 'The Conversation', 1974, 113),
#  (2193215, 'The Counselor', 2013, 117),
#  (68421, 'The Cowboys', 1972, 134),
#  (2150371, 'The Crossing', 2014, 129),
#  (4027270, 'The Crossing 2', 2015, 131),
#  (8981, 'The Cruise of the Make-Believes', 1918, 50),
#  (168622, 'The Crystal Gazer', 1917, 50),
#  (468569, 'The Dark Knight', 2008, 152),
#  (1345836, 'The Dark Knight Rises', 2012, 164),
#  (382625, 'The Da Vinci Code', 2006, 149),
#  (26267, 'The Dawn Rider', 1935, 53),
#  (94963, 'The Dead Pool', 1988, 91),
#  (21507, 'The Deceiver', 1931, 66),
#  (407887, 'The Departed', 2006, 151),
#  (26273, 'The Desert Trail', 1935, 54),
#  (118972, "The Devil's Own", 1997, 111),
#  (71930, 'The Dragon Tamers', 1975, 107),
#  (17832, 'The Drop Kick', 1927, 62),
#  (75968, 'The Duellists', 1977, 100),
#  (72926, 'The Eiger Sanction', 1975, 129),
#  (74483, 'The Enforcer', 1976, 96),
#  (83907, 'The Evil Dead', 1981, 85),
#  (1320253, 'The Expendables', 2010, 103),
#  (1764651, 'The Expendables 2', 2012, 103),
#  (2333784, 'The Expendables 3', 2014, 126),
#  (18876, "The Farmer's Wife", 1928, 100),
#  (232500, 'The Fast and the Furious', 2001, 106),
#  (463985, 'The Fast and the Furious: Tokyo Drift', 2006, 104),
#  (4630562, 'The Fate of the Furious', 2017, 136),
#  (41361, 'The Fighting Kentuckian', 1949, 100),
#  (36824, 'The Fighting Seabees', 1944, 100),
#  (49212, 'The First Traveling Saleslady', 1956, 92),
#  (109813, 'The Flintstones', 1994, 91),
#  (19895, 'The Forward Pass', 1929, 78),
#  (1438461, 'The Founding of a Republic', 2009, 138),
#  (54898, 'The Frightened City', 1961, 97),
#  (116365, 'The Frighteners', 1996, 110),
#  (79180, 'The Frisco Kid', 1979, 119),
#  (106977, 'The Fugitive', 1993, 130),
#  (77588, 'The Fury', 1978, 118),
#  (76070, 'The Gauntlet', 1977, 109),
#  (68638, 'The Getaway', 1972, 123),
#  (219699, 'The Gift', 2000, 112),
#  (17936, 'The Girl in the Pullman', 1927, 60),
#  (119216, 'The Good Life', 1997, 95),
#  (60196, 'The Good, the Bad and the Ugly', 1966, 161),
#  (460810, 'The Great Buck Howard', 2008, 90),
#  (57115, 'The Great Escape', 1963, 172),
#  (59245, 'The Greatest Story Ever Told', 1965, 260),
#  (16939, 'The Great K & A Train Robbery', 1926, 53),
#  (79240, 'The Great Train Robbery', 1978, 110),
#  (63035, 'The Green Berets', 1968, 142),
#  (120689, 'The Green Mile', 1999, 189),
#  (99703, 'The Grifters', 1990, 110),
#  (73694, 'The Hand of Death', 1976, 95),
#  (462329, 'The Hard Corps', 2006, 110),
#  (3460252, 'The Hateful Eight', 2015, 168),
#  (47086, 'The High and the Mighty', 1954, 147),
#  (59274, 'The Hill', 1965, 123),
#  (903624, 'The Hobbit: An Unexpected Journey', 2012, 169),
#  (2310332, 'The Hobbit: The Battle of the Five Armies', 2014, 144),
#  (1170358, 'The Hobbit: The Desolation of Smaug', 2013, 161),
#  (54989, 'The Honeymoon Machine', 1961, 87),
#  (52902, 'The Horse Soldiers', 1959, 120),
#  (468492, 'The Host', 2006, 120),
#  (32609, 'The House Across the Bay', 1940, 88),
#  (101670, 'The House on Tombstone Hill', 1989, 95),
#  (110074, 'The Hudsucker Proxy', 1994, 111),
#  (80907, 'The Hunter', 1980, 97),
#  (99810, 'The Hunt for Red October', 1990, 135),
#  (23038, 'The Hurricane Express', 1932, 227),
#  (1951181, 'The Immigrant', 2013, 120),
#  (1302006, 'The Irishman', 2019, 209),
#  (129167, 'The Iron Giant', 1999, 86),
#  (3040964, 'The Jungle Book', 2016, 106),
#  (416891, 'The Kid & I', 2005, 93),
#  (97202, 'The Killer', 1989, 111),
#  (85794, 'The King of Comedy', 1982, 109),
#  (335245, 'The Ladykillers', 2004, 104),
#  (30341, 'The Lady Vanishes', 1938, 96),
#  (1549920, 'The Last Stand', 2013, 107),
#  (95497, 'The Last Temptation of Christ', 1988, 164),
#  (1618442, 'The Last Witch Hunter', 2015, 106),
#  (25373, 'The Lawless Frontier', 1934, 59),
#  (27876, 'The Lawless Nineties', 1936, 55),
#  (311429, 'The League of Extraordinary Gentlemen', 2003, 110),
#  (146984, 'The Legend of Bagger Vance', 2000, 126),
#  (24257, 'The Life of Jimmy Dolan', 1933, 88),
#  (93428, 'The Living Daylights', 1987, 130),
#  (103074, 'Thelma & Louise', 1991, 130),
#  (17075, 'The Lodger: A Story of the London Fog', 1927, 68),
#  (27905, 'The Lonely Trail', 1936, 56),
#  (56197, 'The Longest Day', 1962, 178),
#  (70334, 'The Long Goodbye', 1973, 112),
#  (32728, 'The Long Voyage Home', 1940, 105),
#  (120737, 'The Lord of the Rings: The Fellowship of the Ring', 2001, 178),
#  (167260, 'The Lord of the Rings: The Return of the King', 2003, 201),
#  (167261, 'The Lord of the Rings: The Two Towers', 2002, 179),
#  (71772, 'The Lords of Flatbush', 1974, 86),
#  (119567, 'The Lost World: Jurassic Park', 1997, 129),
#  (10389, 'The Lottery Man', 1919, 50),
#  (380510, 'The Lovely Bones', 2009, 135),
#  (25440, 'The Lucky Texan', 1934, 55),
#  (16062, 'The Mad Marriage', 1925, 50),
#  (54047, 'The Magnificent Seven', 1960, 128),
#  (24293, 'The Man from Monterey', 1933, 57),
#  (25455, 'The Man from Utah', 1934, 55),
#  (25452, 'The Man Who Knew Too Much', 1934, 75),
#  (49470, 'The Man Who Knew Too Much', 1956, 120),
#  (56217, 'The Man Who Shot Liberty Valance', 1962, 123),
#  (243133, "The Man Who Wasn't There", 2001, 116),
#  (73341, 'The Man Who Would Be King', 1975, 129),
#  (89543, 'The Man with One Red Shoe', 1985, 92),
#  (71807, 'The Man with the Golden Gun', 1974, 125),
#  (20142, 'The Manxman', 1929, 110),
#  (16093, 'The Marriage Whirl', 1925, 80),
#  (3659388, 'The Martian', 2015, 144),
#  (1560747, 'The Master', 2012, 138),
#  (66090, 'The Molly Maguires', 1970, 124),
#  (91541, 'The Money Pit', 1986, 91),
#  (91557, 'The Mosquito Coast', 1986, 117),
#  (16127, 'The Mountain Eagle', 1926, 57),
#  (7959026, 'The Mule', 2018, 116),
#  (164108, 'The Muse', 1999, 97),
#  (8351, 'The Mysterious Mrs. Musslewhite', 1917, 50),
#  (91605, 'The Name of the Rose', 1986, 130),
#  (17201, 'The Nervous Wreck', 1926, 70),
#  (26774, 'The New Frontier', 1935, 54),
#  (74962, 'The Next Man', 1976, 108),
#  (31722, 'The Night Riders', 1939, 56),
#  (70468, 'The Offence', 1973, 112),
#  (13449, 'The Old Homestead', 1922, 80),
#  (193364, 'The Order', 2001, 89),
#  (28068, 'The Oregon Trail', 1936, 59),
#  (75029, 'The Outlaw Josey Wales', 1976, 135),
#  (374463, 'The Pacific', 2010, 530),
#  (395699, 'The Pacifier', 2005, 95),
#  (39694, 'The Paradine Case', 1947, 125),
#  (65904, "The Party at Kitty and Stud's", 1970, 71),
#  (16230, 'The Pleasure Garden', 1925, 75),
#  ...]

# %%
# attaque evitée => erreur soit effet nul
# with conn2.cursor() as cursor:
#     cursor.execute(sql_movie_year_duration2, {'year': '1990 OR 1=1', 'min_duration': '100 OR 1=1'})
#     data = list(cursor)
# data

# %% [markdown]
# ## Connexion via SQLAlchemy

# %%
url = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}'
engine = create_engine(url)
engine
# Out:
# Engine(postgresql+psycopg2://movie:***@localhost:5432/dbmovie)

# %%
movies = pd.read_sql_table('movie', con=engine)
movies
# Out:
#            id                            title  year  duration  \
# 0        5257                        Excuse Me  1915      50.0
# 1        6366               Anton the Terrible  1916      50.0
# 2        8351  The Mysterious Mrs. Musslewhite  1917      50.0
# 3        8384                     On the Level  1917      50.0
# 4        8642                 The Sunset Trail  1917      50.0
# ...       ...                              ...   ...       ...
# 1182  7763324                  Amazing Stories  1986     111.0
# 1183  7816392                      The Bouncer  2018      94.0
# 1184  7903530                     We Die Young  2019      92.0
# 1185  7959026                         The Mule  2018     116.0
# 1186  8079248                        Yesterday  2019     116.0
#
#                                                synopsis  \
# 0     Henry Mallory, U.S.A., receives orders to join...
# 1     Presumably, the first woman ever to appear in ...
# 2     Raymond Van Seer, wealthy, has become morose a...
# 3     Merlin Warner, a sheep rancher's only child, e...
# 4     Tomboy Bess Aiken grows up quickly when her mo...
# ...                                                 ...
# 1182                                               None
# 1183  The hero independently raises his little daugh...
# 1184                                               None
# 1185  Clint Eastwood stars as Earl Stone, a man who ...
# 1186  In Lowestoft UK, Jack Malik is a frustrated mu...
#
#                                              poster_uri color pg  director_id
# 0     https://m.media-amazon.com/images/M/MV5BMmVmMG...  None  R       767303
# 1     https://m.media-amazon.com/images/M/MV5BMWZiZj...  None  R       210352
# 2     https://m.media-amazon.com/images/M/MV5BMTA0Nj...  None  R       916665
# 3     https://m.media-amazon.com/images/M/MV5BMTE5ZT...  None  R       577654
# 4     https://m.media-amazon.com/images/M/MV5BYjk3OT...  None  R       577654
# ...                                                 ...   ... ..          ...
# 1182  https://m.media-amazon.com/images/M/MV5BMGZkZj...  None  R       213100
# 1183  https://m.media-amazon.com/images/M/MV5BNzU3Mz...  None  R      2182866
# 1184  https://m.media-amazon.com/images/M/MV5BZWRjYz...  None  R      1942069
# 1185  https://m.media-amazon.com/images/M/MV5BMTc1OT...  None  R          142
# 1186  https://m.media-amazon.com/images/M/MV5BMjQ0NT...  None  R          965
#
# [1187 rows x 9 columns]

# %%
# params: year et min_duration
sql_movie_year_duration4 = """SELECT
    id,
    title,
    year,
    duration
FROM movie
WHERE 
    year = :year
    AND duration >= :min_duration
ORDER BY title"""

# %%
params={
    'year': 1990, 
    'min_duration': 120
}
movie_selection = pd.read_sql_query(text(sql_movie_year_duration4), con=engine, params=params)
movie_selection
# Out:
#        id                        title  year  duration
# 0   99077                   Awakenings  1990       121
# 1   99426           Bullet in the Head  1990       136
# 2   99685                   Goodfellas  1990       146
# 3  100404            Presumed Innocent  1990       127
# 4   99165  The Bonfire of the Vanities  1990       125
# 5   99810     The Hunt for Red October  1990       135
# 6  100514                   The Rookie  1990       120
# 7  100530             The Russia House  1990       123

# %%
with engine.connect() as conn:
    data = list(conn.execute(text(sql_movie_year_duration4), params))
data
# Out:
# [(99077, 'Awakenings', 1990, 121),
#  (99426, 'Bullet in the Head', 1990, 136),
#  (99685, 'Goodfellas', 1990, 146),
#  (100404, 'Presumed Innocent', 1990, 127),
#  (99165, 'The Bonfire of the Vanities', 1990, 125),
#  (99810, 'The Hunt for Red October', 1990, 135),
#  (100514, 'The Rookie', 1990, 120),
#  (100530, 'The Russia House', 1990, 123)]
